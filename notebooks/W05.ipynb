# %% [markdown]
# # W04A — Cómo “piensa” el motor: **EXPLAIN**, cardinalidad y performance (DuckDB)
#
# **Objetivo:** aprender a **leer planes de ejecución** y detectar los 3 problemas más comunes en analítica:
# 1) **scan enorme** (lees más de lo que necesitas),
# 2) **JOIN que infló** (cardinalidad mal controlada),
# 3) **agregación cara** (filtro tarde / columnas de más).

# %% [markdown]
# ## Bibliografía (W04 en general)
#
# ### Libro guía — **DDIA (Martin Kleppmann)**
# - **Capítulo 3: Storage and Retrieval**
#   Úsalo para: *OLTP vs OLAP, por qué en analítica importa el ancho de banda, column-oriented storage, y por qué el layout/índices cambian el costo de las consultas.*
#
#
# ### Documentación práctica — DuckDB
# - `EXPLAIN` / `EXPLAIN ANALYZE` (planes y cardinalidad)
# - Profiling con `PRAGMA enable_profiling`
# - Índices (`CREATE INDEX`) y tipos de índices (zonemap / ART)

# %%
import os
os.chdir("..")
os.getcwd()
# Out:
# 'c:\\Users\\nancy\\Documents\\Ingenieria_datos'

# %%
from pathlib import Path
import duckdb

PROJECT_ROOT = Path(".").resolve()
RAW_DIR = PROJECT_ROOT / "data" / "raw"
DB_PATH = PROJECT_ROOT / "data" / "exoplanets.duckdb"
ART_DIR = PROJECT_ROOT / "artifacts"
DOCS_DIR = PROJECT_ROOT / "docs"

RAW_DIR.mkdir(parents=True, exist_ok=True)
ART_DIR.mkdir(parents=True, exist_ok=True)
DOCS_DIR.mkdir(parents=True, exist_ok=True)

con = duckdb.connect(str(DB_PATH))

raw_csv = RAW_DIR / "pscomppars.csv"
if not raw_csv.exists():
    raise FileNotFoundError(
        f"No encuentro {raw_csv}. Necesitas el CSV de W01/W02."
    )

def sql_quote(s: str) -> str:
    return "'" + s.replace("'", "''") + "'"

con.execute(f'''
CREATE OR REPLACE VIEW raw_ps AS
SELECT * FROM read_csv_auto({sql_quote(str(raw_csv.resolve()))})
''')

# Si ya tienes Silver/Facts de W03B, perfecto. Si no, los construimos rápido aquí (idéntico a W03B).
con.execute("DROP TABLE IF EXISTS silver_planet")
con.execute('''
CREATE TABLE silver_planet AS
SELECT
  pl_name,
  hostname,
  discoverymethod,
  disc_year,
  sy_snum,
  sy_pnum,
  sy_dist,
  ra,
  dec,
  pl_orbper,
  pl_rade,
  pl_bmasse,
  pl_eqt,
  st_teff,
  st_rad,
  st_mass
FROM raw_ps
WHERE pl_name IS NOT NULL
  AND hostname IS NOT NULL
  AND (disc_year IS NULL OR (disc_year BETWEEN 1980 AND 2026))
  AND (pl_rade  IS NULL OR (pl_rade  > 0 AND pl_rade  <= 30))
  AND (pl_bmasse IS NULL OR (pl_bmasse > 0))
''')

con.execute("DROP TABLE IF EXISTS dim_host_full")
con.execute('''
CREATE TABLE dim_host_full AS
SELECT
  hostname,
  MAX(sy_dist)  AS sy_dist,
  MAX(ra)       AS ra,
  MAX(dec)      AS dec,
  MAX(st_teff)  AS st_teff,
  MAX(st_rad)   AS st_rad,
  MAX(st_mass)  AS st_mass
FROM silver_planet
GROUP BY hostname
''')

con.execute("DROP TABLE IF EXISTS fact_planet")
con.execute('''
CREATE TABLE fact_planet AS
SELECT DISTINCT
  pl_name,
  hostname,
  discoverymethod,
  disc_year,
  pl_orbper,
  pl_rade,
  pl_bmasse,
  pl_eqt
FROM silver_planet
''')

con.sql("SELECT COUNT(*) AS n_fact, COUNT(DISTINCT pl_name) AS n_pl, COUNT(DISTINCT hostname) AS n_hosts FROM fact_planet").show()
# Out:
# ┌────────┬───────┬─────────┐
# │ n_fact │ n_pl  │ n_hosts │
# │ int64  │ int64 │  int64  │
# ├────────┼───────┼─────────┤
# │   6101 │  6101 │    4550 │
# └────────┴───────┴─────────┘

# %% [markdown]
# ## 1) Qué vamos a mirar en un plan (lectura rápida)
#
# Cuando mires `EXPLAIN`, busca:
# - **SCAN**: ¿está leyendo demasiadas filas/columnas?
# - **FILTER**: ¿se aplica temprano o tarde?
# - **JOIN**: ¿qué tipo? (HASH JOIN típico en analítica)
# - **GROUP BY**: ¿cuántas filas entran?
# - **CARDINALIDAD**: cuántas filas pasan por cada operador
#
# `EXPLAIN` = estimado
# `EXPLAIN ANALYZE` = real (ejecuta y muestra cardinalidad real + tiempos)

# %%
# TU TURNO 1: pega aquí una consulta tipo "métrica" y mira su plan.
# Debe tener: WHERE + GROUP BY (como en W02A).
# Ejemplo de idea: por disc_year o por discoverymethod.

q = '''
SELECT
    discoverymethod,
    disc_year,
    COUNT(*) AS n_planets
FROM fact_planet
WHERE disc_year >= 2010
GROUP BY discoverymethod, disc_year
ORDER BY disc_year, n_planets DESC
'''

print("=" * 50)
print("EXPLAIN (plan estimado)")
print("=" * 50)
print(con.sql("EXPLAIN " + q).fetchone()[1])

print("\n" + "=" * 50)
print("EXPLAIN ANALYZE (plan real)")
print("=" * 50)
print(con.sql("EXPLAIN ANALYZE " + q).fetchone()[1])
# Out:
# ==================================================
# EXPLAIN (plan estimado)
# ==================================================
# ┌───────────────────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │             #0            │
# │__internal_decompress_integ│
# │    ral_bigint(#1, 2010)   │
# │             #2            │
# │                           │
# │          ~0 rows          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │          ORDER_BY         │
# │    ────────────────────   │
# │      exoplanets.main      │
# │ .fact_planet.disc_year ASC│
# │     count_star() DESC     │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │             #0            │
# │__internal_compress_integra│
# │    l_utinyint(#1, 2010)   │
# │             #2            │
# │                           │
# │         ~370 rows         │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │             #0            │
# │__internal_decompress_integ│
# │    ral_bigint(#1, 2010)   │
# │             #2            │
# │                           │
# │         ~370 rows         │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │       HASH_GROUP_BY       │
# │    ────────────────────   │
# │          Groups:          │
# │             #0            │
# │             #1            │
# │                           │
# │        Aggregates:        │
# │        count_star()       │
# │                           │
# │         ~370 rows         │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │      discoverymethod      │
# │         disc_year         │
# │                           │
# │        ~1,220 rows        │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │__internal_compress_integra│
# │    l_utinyint(#0, 2010)   │
# │             #1            │
# │                           │
# │        ~1,220 rows        │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         SEQ_SCAN          │
# │    ────────────────────   │
# │     Table: fact_planet    │
# │   Type: Sequential Scan   │
# │                           │
# │        Projections:       │
# │         disc_year         │
# │      discoverymethod      │
# │                           │
# │          Filters:         │
# │      disc_year>=2010      │
# │                           │
# │        ~1,220 rows        │
# └───────────────────────────┘
#
#
# ==================================================
# EXPLAIN ANALYZE (plan real)
# ==================================================
# ┌─────────────────────────────────────┐
# │┌───────────────────────────────────┐│
# ││    Query Profiling Information    ││
# │└───────────────────────────────────┘│
# └─────────────────────────────────────┘
# EXPLAIN ANALYZE  SELECT     discoverymethod,     disc_year,     COUNT(*) AS n_planets FROM fact_planet WHERE disc_year >= 2010 GROUP BY discoverymethod, disc_year ORDER BY disc_year, n_planets DESC
# ┌────────────────────────────────────────────────┐
# │┌──────────────────────────────────────────────┐│
# ││              Total Time: 0.0040s             ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌───────────────────────────┐
# │           QUERY           │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │      EXPLAIN_ANALYZE      │
# │    ────────────────────   │
# │           0 rows          │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │             #0            │
# │__internal_decompress_integ│
# │    ral_bigint(#1, 2010)   │
# │             #2            │
# │                           │
# │          104 rows         │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │          ORDER_BY         │
# │    ────────────────────   │
# │      exoplanets.main      │
# │ .fact_planet.disc_year ASC│
# │     count_star() DESC     │
# │                           │
# │          104 rows         │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │             #0            │
# │__internal_compress_integra│
# │    l_utinyint(#1, 2010)   │
# │             #2            │
# │                           │
# │          104 rows         │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │             #0            │
# │__internal_decompress_integ│
# │    ral_bigint(#1, 2010)   │
# │             #2            │
# │                           │
# │          104 rows         │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │       HASH_GROUP_BY       │
# │    ────────────────────   │
# │          Groups:          │
# │             #0            │
# │             #1            │
# │                           │
# │        Aggregates:        │
# │        count_star()       │
# │                           │
# │          104 rows         │
# │          (0.01s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │      discoverymethod      │
# │         disc_year         │
# │                           │
# │         5,692 rows        │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │__internal_compress_integra│
# │    l_utinyint(#0, 2010)   │
# │             #1            │
# │                           │
# │         5,692 rows        │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         TABLE_SCAN        │
# │    ────────────────────   │
# │     Table: fact_planet    │
# │   Type: Sequential Scan   │
# │                           │
# │        Projections:       │
# │         disc_year         │
# │      discoverymethod      │
# │                           │
# │          Filters:         │
# │      disc_year>=2010      │
# │                           │
# │         5,692 rows        │
# │          (0.00s)          │
# └───────────────────────────┘

# %%
# TU TURNO 2: escribe dos consultas equivalentes:
# A) con SELECT * y B) con solo 3 columnas.
# Luego compara sus planes.

qA = '''
SELECT *
FROM fact_planet
WHERE disc_year >= 2015
'''
qB = '''
SELECT pl_name, hostname, disc_year
FROM fact_planet
WHERE disc_year >= 2015
'''

print("=" * 50)
print("A (SELECT *)")
print("=" * 50)
print(con.sql("EXPLAIN " + qA).fetchone()[1])

print("\n" + "=" * 50)
print("B (SELECT skinny)")
print("=" * 50)
print(con.sql("EXPLAIN " + qB).fetchone()[1])
# Out:
# ==================================================
# A (SELECT *)
# ==================================================
# ┌───────────────────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │          pl_name          │
# │          hostname         │
# │      discoverymethod      │
# │         disc_year         │
# │         pl_orbper         │
# │          pl_rade          │
# │         pl_bmasse         │
# │           pl_eqt          │
# │                           │
# │        ~1,220 rows        │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         SEQ_SCAN          │
# │    ────────────────────   │
# │     Table: fact_planet    │
# │   Type: Sequential Scan   │
# │                           │
# │        Projections:       │
# │         disc_year         │
# │          pl_name          │
# │          hostname         │
# │      discoverymethod      │
# │         pl_orbper         │
# │          pl_rade          │
# │         pl_bmasse         │
# │           pl_eqt          │
# │                           │
# │          Filters:         │
# │      disc_year>=2015      │
# │                           │
# │        ~1,220 rows        │
# └───────────────────────────┘
#
#
# ==================================================
# B (SELECT skinny)
# ==================================================
# ┌───────────────────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │          pl_name          │
# │          hostname         │
# │         disc_year         │
# │                           │
# │        ~1,220 rows        │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         SEQ_SCAN          │
# │    ────────────────────   │
# │     Table: fact_planet    │
# │   Type: Sequential Scan   │
# │                           │
# │        Projections:       │
# │         disc_year         │
# │          pl_name          │
# │          hostname         │
# │                           │
# │          Filters:         │
# │      disc_year>=2015      │
# │                           │
# │        ~1,220 rows        │
# └───────────────────────────┘

# %%
# TU TURNO 3: valida un JOIN sano con evidencia
# 1) arma un JOIN fact_planet + dim_host_full (LEFT JOIN)
# 2) muestra EXPLAIN
# 3) muestra n_fact vs n_join

q_join = '''
SELECT
    f.hostname,
    d.st_teff,
    COUNT(f.pl_name) AS n_planets
FROM fact_planet f
LEFT JOIN dim_host_full d USING (hostname)
GROUP BY f.hostname, d.st_teff
ORDER BY n_planets DESC
LIMIT 20
'''

print("=== EXPLAIN del JOIN ===")
print(con.sql("EXPLAIN " + q_join).fetchone()[1])

# Contar filas para verificar que el JOIN no infla
n_fact = con.sql("SELECT COUNT(*) FROM fact_planet").fetchone()[0]

n_join = con.sql('''
SELECT COUNT(*)
FROM fact_planet f
LEFT JOIN dim_host_full d USING (hostname)
''').fetchone()[0]

print(f"\nn_fact  = {n_fact}")
print(f"n_join  = {n_join}")
print(f"¿JOIN sano? {'✅ Sí' if n_fact == n_join else '❌ Inflado — revisa duplicados en dim_host_full'}")
# Out:
# === EXPLAIN del JOIN ===
# ┌───────────────────────────┐
# │           TOP_N           │
# │    ────────────────────   │
# │          Top: 20          │
# │                           │
# │         Order By:         │
# │   count(f.pl_name) DESC   │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │       HASH_GROUP_BY       │
# │    ────────────────────   │
# │          Groups:          │
# │             #0            │
# │             #1            │
# │                           │
# │        Aggregates:        │
# │        count_star()       │
# │                           │
# │        ~6,099 rows        │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │          hostname         │
# │          st_teff          │
# │                           │
# │        ~6,101 rows        │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         HASH_JOIN         │
# │    ────────────────────   │
# │      Join Type: LEFT      │
# │                           │
# │        Conditions:        ├──────────────┐
# │    hostname = hostname    │              │
# │                           │              │
# │        ~6,101 rows        │              │
# └─────────────┬─────────────┘              │
# ┌─────────────┴─────────────┐┌─────────────┴─────────────┐
# │         SEQ_SCAN          ││         SEQ_SCAN          │
# │    ────────────────────   ││    ────────────────────   │
# │     Table: fact_planet    ││    Table: dim_host_full   │
# │   Type: Sequential Scan   ││   Type: Sequential Scan   │
# │                           ││                           │
# │        Projections:       ││        Projections:       │
# │          hostname         ││          hostname         │
# │          pl_name          ││          st_teff          │
# │                           ││                           │
# │        ~6,101 rows        ││        ~4,550 rows        │
# └───────────────────────────┘└───────────────────────────┘
#
#
# n_fact  = 6101
# n_join  = 6101
# ¿JOIN sano? ✅ Sí

# %% [markdown]
# ## Para entregar (W04A) — mesurado
#
# ### En clase
# 1) `docs/w04a_perf_report.md` con:
#    - 2 planes (`EXPLAIN`) pegados (consulta tuya + JOIN)
#    - 2 conclusiones cortas (2–3 líneas cada una) sobre:
#      - dónde está el costo (SCAN/JOIN/GROUP BY)
#      - qué mejorarías (leer menos columnas, filtrar antes, etc.)
# 2) `docs/decisions_log.md`: 1 decisión:
#    - “Reescribí una consulta para reducir costo” + evidencia (plan antes/después o conteo).
#
# ### Tarea
# 1) Ejecuta `EXPLAIN ANALYZE` sobre 1 consulta y pega el resultado.
# 2) Exporta a `artifacts/` un archivo de evidencia:
#    - `artifacts/w04a_explain_q1.txt` (copiar/pegar plan a texto está bien)

# %% [markdown]
# ## Reflexión (bitácora)
# - ¿Qué parte del plan te costó más interpretar?
# - Si el dataset creciera 100×, ¿qué operador crees que empeora primero (SCAN/JOIN/GROUP BY) y por qué?

# %%
plan_txt = con.sql("EXPLAIN ANALYZE " + q).fetchone()[1]
explain_path = ART_DIR / "w04a_explain_q1.txt"
explain_path.write_text(plan_txt, encoding="utf-8")
print(f"Guardado: {explain_path}")
# Out:
# Guardado: C:\Users\nancy\Documents\Ingenieria_datos\artifacts\w04a_explain_q1.txt
